# %%
from shelf import Shelf
from spider import Spider
from tome import Tome

# %%
shelf = Shelf('samples\\')

# %%
shelf

# %%
anansi = Spider(shelf=shelf)

# %%
anansi.shelf

# %%
anansi.crawl()
# Out:
# me.txt
# Word count: 607
# Counter({' happy': 2, ' fearless': 1, ' free': 1, ' attracted': 1, ' surprise': 1, ' fearful': 1, ' ecstatic': 1})
#
# raliat.txt
# Word count: 268
# Counter({' frustration': 1, 'positive': 1, 'change': 1, 'looked after': 1})
#
# thisis.txt
# Word count: 663
# Counter({' happy': 3, ' sad': 2, ' esteemed': 1, ' powerless': 1, ' fearful': 1})
#
# verygreek.txt
# Word count: 195
# Counter({' adequate': 1, ' free': 1, ' independent': 1})

# %%
t = Tome('samples//me.txt')

# %%
peter = Spider(tome=t)

# %%
peter.crawl()
# Out:
# Word count: 607
# Counter({' happy': 2, ' fearless': 1, ' free': 1, ' attracted': 1, ' surprise': 1, ' fearful': 1, ' ecstatic': 1})
#
# Prior
# becoming
# data
# science
# fellow
# The
# Knowledge
# House
# (TKH),
# I
# taught
# lot
# math
# programming
# concepts
# needed
# become
# data
# scientist.
# The
# problem
# was,
# beyond
# basics,
# I
# mostly
# resource
# hoarding.
# The
# feeling
# buying
# yet
# another
# ML
# book,
# watching
# another
# data
# structure
# video,
# enough
# satisfy
# urge
# something
# "DS
# related".
# I
# adrift
# sea
# YouTube
# videos,
# books,
# blogs;
# I
# missing,
# structure.
# From
# first
# week
# TKH,
# given
# clear
# roadmap
# form
# syllabus,
# information
# tech
# industry,
# required
# make
# target
# sub-field.
# While
# given
# enough
# resources
# could
# choose
# benefited
# us
# best,
# given
# many
# end
# situation
# I
# before.
# It's
# 5
# weeks
# now,
# concepts
# seemed
# difficult
# grasp
# learning
# own,
# became
# ...

# %%
t.unq
# Out:
# {'"DS',
#  '"that',
#  '(TKH),',
#  '(and',
#  '-',
#  '1',
#  '2',
#  '3',
#  '3rd',
#  '5',
#  'AWS),',
#  'Ask',
#  'At',
#  'Finally,',
#  'From',
#  'Here',
#  'House',
#  'I',
#  "I'm",
#  'In',
#  "It's",
#  'Knowledge',
#  'Level',
#  'ML',
#  'No',
#  'Not',
#  'On',
#  'Our',
#  'Prior',
#  'Python',
#  'SQL',
#  'Some',
#  'TKH',
#  'TKH,',
#  'The',
#  'There',
#  'This',
#  'Too',
#  'While',
#  'YouTube',
#  'a',
#  'about',
#  'access',
#  'adrift',
#  'advantageous',
#  'advisement',
#  'afraid',
#  'always',
#  'amazing',
#  'ample',
#  'an',
#  'and',
#  'another',
#  'are',
#  'as',
#  'ask',
#  'asking',
#  'at',
#  'basics,',
#  'basis,',
#  'be',
#  'became',
#  'become',
#  'becoming',
#  'been',
#  'before.',
#  'begin',
#  'benefited',
#  'best,',
#  'beyond',
#  'bit',
#  'blogs;',
#  'bonded',
#  'book,',
#  'books,',
#  'briefly',
#  'buying',
#  'by',
#  'by.',
#  'call',
#  'can',
#  'career',
#  'case',
#  'certain',
#  'challenging,',
#  'change',
# ...

# %%
t.mood
# Out:
# Counter({' fearless': 1,
#          ' happy': 2,
#          ' free': 1,
#          ' attracted': 1,
#          ' surprise': 1,
#          ' fearful': 1,
#          ' ecstatic': 1})

# %%
shelf.vols
# Out:
# ['me.txt', 'raliat.txt', 'thisis.txt', 'verygreek.txt']

# %%
anansi.report
# Out:
# {'me.txt': [607,
#   Counter({' fearless': 1,
#            ' happy': 2,
#            ' free': 1,
#            ' attracted': 1,
#            ' surprise': 1,
#            ' fearful': 1,
#            ' ecstatic': 1})],
#  'raliat.txt': [268,
#   Counter({' frustration': 1, 'positive': 1, 'change': 1, 'looked after': 1})],
#  'thisis.txt': [663,
#   Counter({' esteemed': 1,
#            ' sad': 2,
#            ' happy': 3,
#            ' powerless': 1,
#            ' fearful': 1})],
#  'verygreek.txt': [195,
#   Counter({' adequate': 1, ' free': 1, ' independent': 1})]}

# %%
a = t.mood.most_common()

# %%
a
# Out:
# [(' happy', 2),
#  (' fearless', 1),
#  (' free', 1),
#  (' attracted', 1),
#  (' surprise', 1),
#  (' fearful', 1),
#  (' ecstatic', 1)]

# %%
t.freq
# Out:
# {'Prior': 1,
#  'to': 22,
#  'becoming': 1,
#  'a': 15,
#  'data': 4,
#  'science': 1,
#  'fellow': 1,
#  'at': 4,
#  'The': 4,
#  'Knowledge': 1,
#  'House': 1,
#  '(TKH),': 1,
#  'I': 7,
#  'taught': 1,
#  'myself': 1,
#  'lot': 1,
#  'of': 18,
#  'the': 32,
#  'math': 1,
#  'and': 20,
#  'programming': 1,
#  'concepts': 2,
#  'needed': 1,
#  'become': 1,
#  'scientist.': 1,
#  'problem': 1,
#  'was,': 1,
#  'beyond': 1,
#  'basics,': 1,
#  'was': 7,
#  'mostly': 1,
#  'resource': 1,
#  'hoarding.': 1,
#  'feeling': 1,
#  'buying': 1,
#  'yet': 1,
#  'another': 2,
#  'ML': 1,
#  'book,': 1,
#  'or': 1,
#  'watching': 1,
#  'structure': 2,
#  'video,': 1,
#  'just': 2,
#  'enough': 2,
#  'satisfy': 1,
#  'my': 3,
#  'urge': 1,
#  'do': 1,
#  'something': 1,
#  '"DS': 1,
#  'related".': 1,
#  'adrift': 1,
#  'in': 15,
#  'sea': 1,
#  'YouTube': 1,
#  'videos,': 1,
#  'books,': 1,
#  'blogs;': 1,
#  'what': 2,
#  'missing,': 1,
#  'structure.': 1,
#  'From': 1,
#  'very': 1,
# ...
